# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
import os

# %%
# read data_processed.csv
data_path = '/content/drive/MyDrive/Colab Notebooks/BT5153/Data/'
df = pd.read_csv(data_path + 'Data_processed.csv')
df.columns = ['img_id', 'title', 'img_url', 'description', 'sex', 'material', 'price', 'brand', 'colour']

df.shape
# Out:
# (50405, 9)

# %%
img_files = os.listdir('/content/drive/MyDrive/Colab Notebooks/BT5153/Data/Pict')
img_ids = [id.split('.')[0] for id in img_files]

df = df[df.img_id.isin(img_ids)]

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/BT5153/Data/Data_processed_reduced.csv', index=False)
# df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/BT5153/Data/Data_processed_reduced.csv')
df.shape
# Out:
# (49111, 9)
