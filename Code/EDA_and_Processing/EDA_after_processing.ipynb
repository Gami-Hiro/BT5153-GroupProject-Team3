# %% [markdown]
# # EDA

# %% [markdown]
# ## Pre-processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import csv
df = pd.read_csv("Data_processed_reduced_v4.csv", encoding= 'unicode_escape')

# %%
# confirm the data frame
df
# Out:
#        Unnamed: 0  img_id                                              title  \
# 0               0       0                           MEN Linen Blended Shorts
# 1               1       1                          MEN Easy Shorts (Printed)
# 2               2       2                                   MEN Chino Shorts
# 3               3       3                  MEN Uniqlo U Wide Fit Easy Shorts
# 4               5       5                             MEN Ultra Light Shorts
# ...           ...     ...                                                ...
# 18675       33329   34592  Levi's x Disney Mickey & Friends Crewneck Swea...
# 18676       33330   34593                 Levi's Cinched Crewneck Sweatshirt
# 18677       33331   34594                   Levi's Diana Crewneck Sweatshirt
# 18678       33334   34597                        Levi's Graphic Sport Hoodie
# 18679       33335   34598          levi  women's graphic skate zip-up hoodie
#
#                                                  img_url  \
# 0      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 1      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 2      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 3      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 4      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# ...                                                  ...
# 18675  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18676  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18677  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18678  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18679  https://storage.sg.content-cdn.io/cdn-cgi/imag...
#
#                                              description    sex  \
# 0      a single layer with a natural feel of natural ...    MEN
# 1      light and cool shorts are perfect for relaxing...    MEN
# 2      updated to have a relaxed silhouette has a mor...    MEN
# 3      shorts inspired by military pants trendy loose...    MEN
# 4      kando shorts has been renamed to ultra light s...    MEN
# ...                                                  ...    ...
# 18675  introducing a special collaboration featuring ...  WOMEN
# 18676  a cozy and casual pullover sweatshirt made esp...  WOMEN
# 18677  a crewneck sweater with a vintage fit dropped ...  WOMEN
# 18678  sportswear style and casual comfort together i...  WOMEN
# 18679  a go to hoodie with a casual style and relaxed...  WOMEN
#
#                     material  price   brand              colour  \
# 0      68% Cotton, 32% Linen   29.9  UNIQLO   Color: COL69 NAVY
# 1                100% Cotton   19.9  UNIQLO  Color: COL37 BROWN
# 2                100% Cotton   29.9  UNIQLO  Color: COL09 BLACK
# 3                100% Cotton   49.9  UNIQLO  Color: COL09 BLACK
# 4             100% Polyester   39.9  UNIQLO  Color: COL32 BEIGE
# ...                      ...    ...     ...                 ...
# 18675                    NaN  119.9  Levi'S                 NaN
# 18676                    NaN  119.9  Levi'S                 NaN
# 18677                    NaN  119.9  Levi'S                 NaN
# 18678                    NaN   99.9  Levi'S                 NaN
# 18679                    NaN   69.9  Levi'S                 NaN
#
#                                              Description
# 0      a single layer with a natural feel of natural ...
# 1      light and cool shorts are perfect for relaxing...
# 2      updated to have a relaxed silhouette has a mor...
# 3      shorts inspired by military pants trendy loose...
# 4      kando shorts has been renamed to ultra light s...
# ...                                                  ...
# 18675  introducing a special collaboration featuring ...
# 18676  a cozy and casual pullover sweatshirt made esp...
# 18677  a crewneck sweater with a vintage fit dropped ...
# 18678  sportswear style and casual comfort together i...
# 18679  a go to hoodie with a casual style and relaxed...
#
# [18680 rows x 11 columns]

# %%
# confirm null data
df.isnull().sum()
# Out:
# Unnamed: 0        0
# img_id            0
# title             0
# img_url           0
# description       0
# sex               0
# material       7956
# price          7151
# brand             0
# colour         7779
# Description       0
# dtype: int64

# %%
# drop data which URL or Descryption is null
df = df.dropna(subset=['img_url', 'Description'])

# %%
df['Description_processed'] = -1
#for i in range(len(df)):
#    df.iloc[i,2] = len(df.iloc[i,2])
def split(text):
    return text.split()
df["Description_processed"]=df["Description"].apply(split)

# %%
df
# Out:
#        Unnamed: 0  img_id                                              title  \
# 0               0       0                           MEN Linen Blended Shorts
# 1               1       1                          MEN Easy Shorts (Printed)
# 2               2       2                                   MEN Chino Shorts
# 3               3       3                  MEN Uniqlo U Wide Fit Easy Shorts
# 4               5       5                             MEN Ultra Light Shorts
# ...           ...     ...                                                ...
# 18675       33329   34592  Levi's x Disney Mickey & Friends Crewneck Swea...
# 18676       33330   34593                 Levi's Cinched Crewneck Sweatshirt
# 18677       33331   34594                   Levi's Diana Crewneck Sweatshirt
# 18678       33334   34597                        Levi's Graphic Sport Hoodie
# 18679       33335   34598          levi  women's graphic skate zip-up hoodie
#
#                                                  img_url  \
# 0      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 1      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 2      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 3      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# 4      https://d15udtvdbbfasl.cloudfront.net/catalog/...
# ...                                                  ...
# 18675  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18676  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18677  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18678  https://storage.sg.content-cdn.io/cdn-cgi/imag...
# 18679  https://storage.sg.content-cdn.io/cdn-cgi/imag...
#
#                                              description    sex  \
# 0      a single layer with a natural feel of natural ...    MEN
# 1      light and cool shorts are perfect for relaxing...    MEN
# 2      updated to have a relaxed silhouette has a mor...    MEN
# 3      shorts inspired by military pants trendy loose...    MEN
# 4      kando shorts has been renamed to ultra light s...    MEN
# ...                                                  ...    ...
# 18675  introducing a special collaboration featuring ...  WOMEN
# 18676  a cozy and casual pullover sweatshirt made esp...  WOMEN
# 18677  a crewneck sweater with a vintage fit dropped ...  WOMEN
# 18678  sportswear style and casual comfort together i...  WOMEN
# 18679  a go to hoodie with a casual style and relaxed...  WOMEN
#
#                     material  price   brand              colour  \
# 0      68% Cotton, 32% Linen   29.9  UNIQLO   Color: COL69 NAVY
# 1                100% Cotton   19.9  UNIQLO  Color: COL37 BROWN
# 2                100% Cotton   29.9  UNIQLO  Color: COL09 BLACK
# 3                100% Cotton   49.9  UNIQLO  Color: COL09 BLACK
# 4             100% Polyester   39.9  UNIQLO  Color: COL32 BEIGE
# ...                      ...    ...     ...                 ...
# 18675                    NaN  119.9  Levi'S                 NaN
# 18676                    NaN  119.9  Levi'S                 NaN
# 18677                    NaN  119.9  Levi'S                 NaN
# 18678                    NaN   99.9  Levi'S                 NaN
# 18679                    NaN   69.9  Levi'S                 NaN
#
#                                              Description  \
# 0      a single layer with a natural feel of natural ...
# 1      light and cool shorts are perfect for relaxing...
# 2      updated to have a relaxed silhouette has a mor...
# 3      shorts inspired by military pants trendy loose...
# 4      kando shorts has been renamed to ultra light s...
# ...                                                  ...
# 18675  introducing a special collaboration featuring ...
# 18676  a cozy and casual pullover sweatshirt made esp...
# 18677  a crewneck sweater with a vintage fit dropped ...
# 18678  sportswear style and casual comfort together i...
# 18679  a go to hoodie with a casual style and relaxed...
#
#                                    Description_processed
# 0      [a, single, layer, with, a, natural, feel, of,...
# 1      [light, and, cool, shorts, are, perfect, for, ...
# 2      [updated, to, have, a, relaxed, silhouette, ha...
# 3      [shorts, inspired, by, military, pants, trendy...
# 4      [kando, shorts, has, been, renamed, to, ultra,...
# ...                                                  ...
# 18675  [introducing, a, special, collaboration, featu...
# 18676  [a, cozy, and, casual, pullover, sweatshirt, m...
# 18677  [a, crewneck, sweater, with, a, vintage, fit, ...
# 18678  [sportswear, style, and, casual, comfort, toge...
# 18679  [a, go, to, hoodie, with, a, casual, style, an...
#
# [18680 rows x 12 columns]

# %%
# add the column of the length of the descryption
df['Length_of_description'] = -1
for i in range(len(df)):
    df.iloc[i,-1] = len(df.iloc[i,2])

# %%
# make df for price analysis
df_del_noprice_data = df.copy()
df_del_noprice_data = df_del_noprice_data.dropna(subset=['price'])

# %% [markdown]
# ## Visualize the statistics of the data

# %%
# statistics of sex
label_sex = list(set(list(df["sex"].values)))
height_sex = []
for i in range(len(label_sex)):
    height_sex.append(list(df["sex"].values).count(label_sex[i]))
plt.bar(label_sex, height_sex, color='teal')
plt.title("Number of data of clothes in each gender", fontsize=14)
plt.xticks(fontsize=14)
plt.tick_params(labelsize=14);

# %%
# statistics of brand
label_brand = list(set(list(df["brand"].values)))
height_brand = []
for i in range(len(label_brand)):
    height_brand.append(list(df["brand"].values).count(label_brand[i]))
    
plt.bar(label_brand, height_brand, color='teal')
plt.xticks(rotation=75, fontsize=14)
plt.title("Number of data in each brand", fontsize=14)
plt.tick_params(labelsize=14);

# %%
# statistics of the average length of the explanationv corresponding to sex
height_sex_avedisc = []
for i in range(len(label_sex)):
    height_sex_avedisc.append(df[df.sex == label_sex[i] ].Length_of_description.mean())
    
plt.bar(label_sex, height_sex_avedisc, color='teal')
plt.title("Average length for explanation of clothes in each gender", fontsize=14)
plt.xticks(fontsize=14)
plt.tick_params(labelsize=14);

# %%
# statistics of the average length of the explanationv corresponding to brands
height_brand_avedisc = []
for i in range(len(label_brand)):
    height_brand_avedisc.append(df[df.brand == label_brand[i] ].Length_of_description.mean())
    
plt.bar(label_brand, height_brand_avedisc, color='teal')
plt.title("Average length for explanation of clothes in each brand", fontsize=14)
plt.xticks(rotation=75, fontsize=14)
plt.tick_params(labelsize=14);

# %%
# statistics of the average length of the explanationv corresponding to brands
label_brand_price = list(set(list(df_del_noprice_data["brand"].values)))
height_aveprice = []
for i in range(len(label_brand_price)):
    height_aveprice.append(df_del_noprice_data[df_del_noprice_data.brand == label_brand_price[i]].price.mean())
    
plt.bar(label_brand_price, height_aveprice, color='teal')
plt.xticks(rotation=60, fontsize=14)
plt.title("Average price of each brand", fontsize=14)
plt.tick_params(labelsize=14);

# %% [markdown]
# ## Correlation

# %%
# Correlation between the length of explanation and price
height_brand_avedisc_col = []
for i in range(len(label_brand_price)):
    height_brand_avedisc_col.append(df_del_noprice_data[df_del_noprice_data.brand == label_brand_price[i] ].Length_of_description.mean())

np.corrcoef(height_aveprice, height_brand_avedisc_col)
# Out:
# array([[ 1.        , -0.17868559],
#        [-0.17868559,  1.        ]])

# %% [markdown]
# It can be seen that there is a week negative correlation between the price and length of the explanation of clothes. We can regard this results as high-blands tend to explain less. Actually, people tend to know the high blands quality is superior to others without explanation. Also, high-blands often put effort on get their homepage to be stilish. It may cause the result of weak correlation.

# %% [markdown]
# ## Word cloud

# %%
from wordcloud import WordCloud, STOPWORDS

comment_words = '' 
stopwords = set(STOPWORDS) 

# iterate through the csv file 
for val in df['Description']: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
      
    comment_words += " ".join(tokens)+" "
  
wordcloud = WordCloud(width = 800, height = 600, 
                background_color ='white', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (6, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
